# %% [markdown]
# **Goal** : Convert `lcregions.txt` to `lcregions.csv`

# %%
# 0. Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Paths to files
# Input file
source_path = "/u/mdmc/enyanduk/internship_areasciencepark/Data/dpcfam/dpcfam_standard/zenodo_unzipped_folders/metaclusters_xml/mc_info_from_xml/lcregions.txt"
# Output file
target_path = "/u/mdmc/enyanduk/internship_areasciencepark/Dataframes/DPCFam/"

# %%
# Type of file ?
with open(source_path, "r",encoding="utf-8") as f:
  print(repr(f.readline()))
# Out:
# '#MC low_complexity_rate\n'

# %% [markdown]
# `Oberservation` : It is not a `tab`-separated file, it's rather a `spaces`-separated file.

# %%
# Convert to a dataframe
df = pd.read_csv(source_path, sep=r"\s+")
df.head()
# Out:
#    #MC  low_complexity_rate
# 0    1             0.047194
# 1    4             0.049879
# 2   15             0.049560
# 3   19             0.088535
# 4   21             0.026462

# %%
# Infos
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46828 entries, 0 to 46827
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #MC                  46828 non-null  int64
#  1   low_complexity_rate  46828 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 731.8 KB

# %%
# Renaming 
df = df.rename(columns={"#MC": "MCID", "low_complexity_rate": "%LC"})
df["MCID"] = df["MCID"].astype(int)
df.head()
# Out:
#    MCID       %LC
# 0     1  0.047194
# 1     4  0.049879
# 2    15  0.049560
# 3    19  0.088535
# 4    21  0.026462

# %%
# Statistics
df.describe().T
# Out:
#         count           mean            std  min           25%            50%  \
# MCID  46828.0  219773.410182  146629.434003  1.0  89277.250000  204258.500000
# %LC   46828.0       0.044257       0.046293  0.0      0.015146       0.028494
#
#                75%            max
# MCID  341567.50000  504487.000000
# %LC        0.05603       0.499669

# %%
# Save to csv 
final_target = target_path + "lcregions.csv"
df.to_csv(final_target, index=False)
