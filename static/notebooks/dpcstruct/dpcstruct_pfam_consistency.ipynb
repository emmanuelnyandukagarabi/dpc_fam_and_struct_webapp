# %% [markdown]
# **File** : ``pfam_consistency.tsv``

# %% [markdown]
# # I. Installation and Data Loading

# %%
# Imports
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Path to data
path_to_data = "/u/mdmc/enyanduk/internship_areasciencepark/Data/dpcstruct/pfam_consistency.tsv"

# %%
with open(path_to_data, "r",encoding="utf-8") as f:
  print(repr(f.readline()))
# Out:
# 'PfamID score DPCstruct-label\n'

# %% [markdown]
# `Oberservation` : It's  a `spaces`-separated file.

# %%
# Read in the data
df = pd.read_csv(path_to_data, sep=r"\s+")
df.head()
# Out:
#    PfamID     score               DPCstruct-label
# 0  CL0001  0.577698  56862-55086-22463-4358-47813
# 1  CL0003  0.070468    24800-36176-37984-275-4452
# 2  CL0004  0.566181  32775-2976-21811-55086-61848
# 3  CL0005  0.735225  58948-4452-35673-61388-10731
# 4  CL0007  0.686627  37573-45182-49202-6006-19588

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5563 entries, 0 to 5562
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PfamID           5563 non-null   object
#  1   score            5563 non-null   float64
#  2   DPCstruct-label  5563 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 130.5+ KB

# %% [markdown]
# # II. Data Profiling Report

# %%
# Profiling the dataset
profile = ProfileReport(df, title="Pfam-DPCstruct Profiling Report", explorative=True)
path_to_report = "/u/mdmc/enyanduk/internship_areasciencepark/Notebooks/profiling_reports/pfam_dpcstruct_report.html"
profile.to_file(path_to_report)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-04-24 15:50:04.553757&quot; name=date&gt;&lt;title&gt;Pfam-DPCstruct Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# We save the dataframe as csv file.
output_path = "/u/mdmc/enyanduk/internship_areasciencepark/Dataframes/DPCStruct/pfam_consistency.csv"
df.to_csv(output_path, index=False)
